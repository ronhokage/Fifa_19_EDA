# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('....\\data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data.isnull().values.any() # To check if any null values exist in the dataset
# Out:
# True

# %%
data.tail()
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %%
data[data.Club.isnull()] # Values Null in Club
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 452           452  207439      L. Paredes   24
# 538           538  156713    A. Granqvist   33
# 568           568  229909        A. Lunev   26
# 677           677  187347    I. Smolnikov   29
# 874           874  187607       A. Dzyuba   29
# ...           ...     ...             ...  ...
# 17197       17197  245164        V. Kaith   21
# 17215       17215  243131        K. Taimi   26
# 17339       17339  233526        S. Passi   23
# 17436       17436  236452  D. Lalhlimpuia   20
# 17539       17539  234508        C. Singh   21
#
#                                                 Photo Nationality  \
# 452    https://cdn.sofifa.org/players/4/19/207439.png   Argentina
# 538    https://cdn.sofifa.org/players/4/19/156713.png      Sweden
# 568    https://cdn.sofifa.org/players/4/19/229909.png      Russia
# 677    https://cdn.sofifa.org/players/4/19/187347.png      Russia
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %% [markdown]
# ## Data preprocessing Stage

# %%
data['Club']=data['Club'].fillna('No Club',inplace=True)
data['Composure']=data['Composure'].fillna(data['Composure'].mean())
data['Marking']=data['Marking'].fillna(data['Marking'].mean())
data['StandingTackle']=data['StandingTackle'].fillna(data['StandingTackle'].mean())
data['SlidingTackle']=data['SlidingTackle'].fillna(data['SlidingTackle'].mean())
data['GKDiving']=data['GKDiving'].fillna(data['GKDiving'].mean())

# %%
data
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %% [markdown]
# ## Dream Team to have- Top Players

# %%
#The best players in the lot
data.loc[data['Overall']>=90]
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# ...

# %% [markdown]
# ## Left V/S Right Foot

# %%
#Preffered Foot Analysis
sns.countplot(x='Preferred Foot',data=data)
plt.title('Left V/S Right Foot')
data['Preferred Foot'].value_counts()
# Out:
# Right    13948
# Left      4211
# Name: Preferred Foot, dtype: int64

# %% [markdown]
# ## Players Nationality Wise

# %%
sns.countplot(x='Nationality',data=data)
#As per the data seen below it's quite huge and would be difficult to interpret.Hence, Lets go for top 20 Nationality analysis.
# Out:
# <AxesSubplot:xlabel='Nationality', ylabel='count'>

# %%
#Lets create a separate Dataframe to show Nations and their player count
cn1=data['Nationality'].value_counts()
cn=cn1.reset_index()
cn.columns=["Nationality","Counts"]
cn.head()
# Out:
#   Nationality  Counts
# 0     England    1662
# 1     Germany    1198
# 2       Spain    1072
# 3   Argentina     937
# 4      France     914

# %%
cn['Counts']
# Out:
# 0      1662
# 1      1198
# 2      1072
# 3       937
# 4       914
#        ...
# 159       1
# 160       1
# 161       1
# 162       1
# 163       1
# Name: Counts, Length: 164, dtype: int64

# %%
ncv=cn.iloc[:20]
ncv
# Out:
#             Nationality  Counts
# 0               England    1662
# 1               Germany    1198
# 2                 Spain    1072
# 3             Argentina     937
# 4                France     914
# 5                Brazil     827
# 6                 Italy     702
# 7              Colombia     618
# 8                 Japan     478
# 9           Netherlands     453
# 10               Sweden     397
# 11             China PR     392
# 12                Chile     391
# 13  Republic of Ireland     368
# 14               Mexico     366
# 15        United States     353
# 16               Poland     350
# 17               Norway     341
# 18         Saudi Arabia     340
# 19              Denmark     336

# %%
sns.catplot(y="Counts",
            x="Nationality",data=ncv,
            palette="RdBu",height=5,kind="bar",aspect=4)
plt.title("Top 20 Players Nationality Wise",
          fontsize=20);

# %% [markdown]
# ## Top Paid Players

# %%
data['Wage'].head(10)
# Out:
# 0    €565K
# 1    €405K
# 2    €290K
# 3    €260K
# 4    €355K
# 5    €340K
# 6    €420K
# 7    €455K
# 8    €380K
# 9     €94K
# Name: Wage, dtype: object

# %%
#Removing the unecessary characters in the wage
def Wage_func(Value):
    change = Value.replace("€", "")
    if "M" in change:
        change = float(change.replace("M",""))*1000000
    elif "K" in change:
        change = float(change.replace("K", "")) * 1000
    return float(change)

# %%
data["Wage"] = data["Wage"].apply(lambda x: Wage_func(x))

# %%
data['Wage'].dtype
# Out:
# dtype('float64')

# %%
#Top 10 paid players
c=data.sort_values(by='Wage',ascending=False)
c['Name'].head(10)
# Out:
# 0              L. Messi
# 7             L. Suárez
# 6             L. Modrić
# 1     Cristiano Ronaldo
# 8          Sergio Ramos
# 11             T. Kroos
# 36              G. Bale
# 4          K. De Bruyne
# 5             E. Hazard
# 32             Coutinho
# Name: Name, dtype: object

# %% [markdown]
# ## Distribution of Players

# %%
#Let us create a seperate dataframe to check the position of the players
pos=data['Position'].value_counts().reset_index()
pos.coloumns=['Count']
pos.head()
# Out:
# D:\anaconda\envs\fifa_kaggle\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index  Position
# 0    ST      2152
# 1    GK      2025
# 2    CB      1778
# 3    CM      1394
# 4    LB      1322

# %%
sns.catplot(y="Position",
            x="index",data=pos,
            palette="GnBu",height=5,kind="bar",aspect=3)
plt.title("Distribution wrt position of Players",
          fontsize=20);

# %% [markdown]
# ## To Check Contract Validity

# %%
data['Contract Valid Until'].value_counts()
# Out:
# 2019            4819
# 2021            4360
# 2020            4027
# 2022            1477
# 2023            1053
# Jun 30, 2019     931
# 2018             886
# Dec 31, 2018     144
# May 31, 2019      60
# Jan 1, 2019       51
# 2024              23
# Jun 30, 2020      14
# Jan 31, 2019      13
# 2025               7
# Jan 5, 2019        6
# Jan 2, 2019        6
# Oct 14, 2019       5
# Jan 12, 2019       5
# Jan 6, 2019        4
# Jan 25, 2019       3
# Jan 7, 2019        3
# Dec 31, 2019       3
# May 31, 2020       2
# Dec 1, 2019        2
# 2026               2
# Nov 30, 2018       2
# Jan 18, 2019       1
# Jan 20, 2019       1
# Jan 3, 2019        1
# May 4, 2019        1
# Jan 15, 2019       1
# Jan 11, 2019       1
# Jun 1, 2019        1
# Jan 30, 2019       1
# Jan 4, 2019        1
# Feb 27, 2020       1
# Name: Contract Valid Until, dtype: int64

# %%
# We are trying to convert the date values to only year values
data['date_column'] = pd.to_datetime(data['Contract Valid Until'])

# %%
#Using datetime technique
data['year'] = pd.DatetimeIndex(data['Contract Valid Until']).year
data['month'] = pd.DatetimeIndex(data['Contract Valid Until']).month

# %%
data['year'].value_counts()
# Out:
# 2019.0    5920
# 2021.0    4360
# 2020.0    4044
# 2022.0    1477
# 2023.0    1053
# 2018.0    1032
# 2024.0      23
# 2025.0       7
# 2026.0       2
# Name: year, dtype: int64

# %%
#Dropping the NaN values wrt year
data.dropna(subset = ["year"], inplace=True)

# %%
#Conversion from float to int
data['year'].astype(int)
# Out:
# 0        2021
# 1        2022
# 2        2022
# 3        2020
# 4        2023
#          ...
# 18202    2019
# 18203    2020
# 18204    2021
# 18205    2019
# 18206    2019
# Name: year, Length: 17918, dtype: int32

# %%
# Well performing players, whose contract is going to expire in 2020
data.loc[(data['year']==2020) & (data['Overall']>=90)]
# Out:
#     Unnamed: 0      ID          Name  Age  \
# 3            3  193080        De Gea   27
# 5            5  183277     E. Hazard   27
# 6            6  177003     L. Modrić   32
# 8            8  155862  Sergio Ramos   32
# 13          13  168542   David Silva   32
#
#                                              Photo Nationality  \
# 3   https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 5   https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6   https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 8   https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 13  https://cdn.sofifa.org/players/4/19/168542.png       Spain
#
#                                    Flag  Overall  Potential  Club  ...  \
# 3   https://cdn.sofifa.org/flags/45.png       91         93  None  ...
# 5    https://cdn.sofifa.org/flags/7.png       91         91  None  ...
# 6   https://cdn.sofifa.org/flags/10.png       91         91  None  ...
# ...

# %% [markdown]
# ## Players with the highest Sprint

# %%
data['SprintSpeed'].mean(axis=0)# Avg sprint for Players
# Out:
# 64.72067194999443

# %%
data.fillna(data["SprintSpeed"].mean()) # Handling the missing values with mean
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
data['SprintSpeed'].astype(int) # Simplying float to int values
# Out:
# 0        86
# 1        91
# 2        90
# 3        58
# 4        76
#          ..
# 18202    57
# 18203    39
# 18204    69
# 18205    60
# 18206    55
# Name: SprintSpeed, Length: 17918, dtype: int32

# %%
# Shows Top 10 players who were the fastest in 2019
data.loc[data['SprintSpeed']>=90].head(10)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 25          25  231747          K. Mbappé   19
# 26          26  209331           M. Salah   26
# 33          33  188567      P. Aubameyang   29
# 36          36  173731            G. Bale   28
# 47          47  192505          R. Lukaku   25
# 49          49  189332         Jordi Alba   29
# 55          55  222492            L. Sané   22
# 58          58  208722            S. Mané   26
#
#                                              Photo Nationality  \
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2   https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 25  https://cdn.sofifa.org/players/4/19/231747.png      France
# 26  https://cdn.sofifa.org/players/4/19/209331.png       Egypt
# 33  https://cdn.sofifa.org/players/4/19/188567.png       Gabon
# ...

# %% [markdown]
# ## Players with Highest Penalties Take

# %%
data.nlargest(20, ['Penalties'])# Shows Top 20 players who had highest penalty take rating in 2019.
# Out:
#       Unnamed: 0      ID            Name  Age  \
# 206          206  186627    M. Balotelli   27
# 118          118  209499         Fabinho   24
# 16            16  202126         H. Kane   24
# 297          297  183574        M. Kruse   30
# 384          384  183900      D. Perotti   29
# 507          507  188388    R. Boudebouz   28
# 823          823  204838      R. Jiménez   27
# 945          945  163631       L. Baines   33
# 68            68  188350         M. Reus   29
# 109          109   41236  Z. Ibrahimović   36
# 3199        3199  164857          Edinho   35
# 10            10  188545  R. Lewandowski   29
# 204          204  189068         B. Dost   29
# 240          240  216354     A. Kramarić   27
# 315          315  113422     David Villa   36
# 456          456  205693       S. Haller   24
# 1274        1274  152879        M. Noble   31
# 3161        3161  181483      M. Jedinák   33
# 610          610  206304  L. Milivojević   27
# ...

# %% [markdown]
# ## Best Goalkeepers

# %%
#Features for consideration, conversion of values from Float to int
data[['GKDiving',                  
'GKHandling',                
'GKKicking',                 
'GKPositioning',             
'GKReflexes']].astype(int)
# Out:
#        GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes
# 0             6          11         15             14           8
# 1             7          11         15             14          11
# 2             9           9         15             15          11
# 3            90          85         87             88          94
# 4            15          13          5             10          13
# ...         ...         ...        ...            ...         ...
# 18202        10          13          7              8           9
# 18203        10           9          9              5          12
# 18204         6           5         10              6          13
# 18205        14           6         14              8           9
# 18206        10          15          9             12           9
#
# [17918 rows x 5 columns]

# %%
#Threshold of 80 was considered for balanced attributes and hence decided to opt for the same.
data.loc[(data['GKDiving']>80) & (data[                
'GKHandling']>80) &                
(data['GKKicking']>80) &                 
(data['GKPositioning']>80) &             
(data['GKReflexes']>80)]
# Out:
#     Unnamed: 0      ID           Name  Age  \
# 3            3  193080         De Gea   27
# 18          18  192448  M. ter Stegen   26
# 22          22  167495       M. Neuer   32
# 81          81  212831        Alisson   25
#
#                                              Photo Nationality  \
# 3   https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 18  https://cdn.sofifa.org/players/4/19/192448.png     Germany
# 22  https://cdn.sofifa.org/players/4/19/167495.png     Germany
# 81  https://cdn.sofifa.org/players/4/19/212831.png      Brazil
#
#                                    Flag  Overall  Potential  Club  ...  \
# 3   https://cdn.sofifa.org/flags/45.png       91         93  None  ...
# 18  https://cdn.sofifa.org/flags/21.png       89         92  None  ...
# 22  https://cdn.sofifa.org/flags/21.png       89         89  None  ...
# 81  https://cdn.sofifa.org/flags/54.png       85         90  None  ...
#
# ...
